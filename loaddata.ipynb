# %%
import pandas as pd

url = 'https://github.com/Genga28/covid-19-data/raw/master/public/data/latest/owid-covid-latest.csv'
df = pd.read_csv(url,error_bad_lines=False)
#df = pd.read_csv(url)

print(df.head(5))
# Out:
# C:\Users\kgeng\AppData\Local\Temp\ipykernel_11024\856067338.py:4: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(url,error_bad_lines=False)
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# ~\anaconda3\lib\urllib\request.py in do_open(self, http_class, req, **http_conn_args)
#    1345             try:
# -> 1346                 h.request(req.get_method(), req.selector, req.data, headers,
#    1347                           encode_chunked=req.has_header('Transfer-encoding'))
#
# ~\anaconda3\lib\http\client.py in request(self, method, url, body, headers, encode_chunked)
#    1284         """Send a complete request to the server."""
# -> 1285         self._send_request(method, url, body, headers, encode_chunked)
#    1286
#
# ...

# %%
import pandas as pd
import json
# open file
with open('https://data.covid19india.org/v4/min/data.min.json', 'r')as file:
    df = pd.DataFrame.from_dict(json.load(file))
# print first 5 records via head() method
print(df.head())
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_11024\2054224659.py in <module>
#       4
#       5 # open file
# ----> 6 with open('https://data.covid19india.org/v4/min/data.min.json', 'r')as file:
#       7     df = pd.DataFrame.from_dict(json.load(file))
#       8 # print first 5 records via head() method
#
# OSError: [Errno 22] Invalid argument: 'https://data.covid19india.org/v4/min/data.min.json'
